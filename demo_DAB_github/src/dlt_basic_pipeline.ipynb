# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Delta Live Tables - Basic Pipeline Example"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import dlt\n",
    "from pyspark.sql.functions import *\n",
    "from pyspark.sql.types import *"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Ingest raw data from a source (e.g., auto loader or external path)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "@dlt.table(\n",
    "  name=\"raw_customers\",\n",
    "  comment=\"The raw customer data loaded from a JSON source\"\n",
    ")\n",
    "def load_raw_customers():\n",
    "    return (spark.read.format(\"json\")\n",
    "                .load(\"/databricks-datasets/retail-org/customers/\")\n",
    "           )"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Transform data - clean or enrich"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "@dlt.table(\n",
    "  name=\"clean_customers\",\n",
    "  comment=\"Cleaned customer data with lowercase names\"\n",
    ")\n",
    "def transform_customers():\n",
    "    df = dlt.read(\"raw_customers\")\n",
    "    return df.withColumn(\"email\", lower(col(\"email\")))"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": ""
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
